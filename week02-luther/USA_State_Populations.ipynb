# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
state_pops = pd.read_csv('USA_Population_of_States_US_Census_Intercensal_Tables_1917-2017.csv')
state_pops.sample(10)
# Out:
#     Year        AK       AL       AR       AZ        CA       CO       CT  \
# 71  1988  541983.0  4023844  2342656  3535183  28464249  3262281  3271953
# 40  1957       NaN  3109000  1733000  1125000  14264000  1664000  2359000
# 62  1979  402753.0  3866248  2271333  2635571  23256880  2849234  3095917
# 8   1925       NaN  2534000  1812000   393000   4730000  1019000  1506000
# 57  1974  341063.0  3626499  2101403  2223196  21173865  2541406  3074047
# 67  1984  513702.0  3951820  2319768  3067135  25844393  3169992  3180014
# 75  1992  588736.0  4154014  2415984  3915740  30974659  3495939  3300712
# 1   1918       NaN  2343000  1749000   320000   3262000   906000  1329000
# 37  1954       NaN  3014000  1734000   933000  12746000  1493000  2249000
# 68  1985  532495.0  3972523  2327046  3183538  26441109  3208723  3201131
#
#         DC      DE    ...            TX       UT       VA      VT       WA  \
# 71  630432  647622    ...      16667022  1689372  6036909  549763  4639893
# ...

# %%
states = ['CA','IL','TX','NY']
for state in states:
    pops = state_pops[state]
    plt.plot(state_pops.Year, pops, label=state)
plt.legend();
